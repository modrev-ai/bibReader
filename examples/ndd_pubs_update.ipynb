# %% [markdown]
# # NeuroData Publication Update Protocol
# This notebook utilizes `pandarize` to parse pubs.bib file from neurodata.io and update the list

# %%
from pandarize.frame import Pandarizer
import pandarize
pandarize.__version__
# Out:
# '0.0.5'

# %%
pdr = Pandarizer()
pdr.load('https://raw.githubusercontent.com/neurodata/neurodata.io/deploy/content/bibs/pubs.bib')
# pdr.load('pubs.bib') #for local file
pdr.fit()

# %%
filepath = 'dev/intermediate.xlsx'
ufilepath = 'dev/intermediate-updated.xlsx'

# %%
pdr.df.to_excel(filepath, index=False, engine='xlsxwriter')

# %% [markdown]
# Make changes to the downloaded and converted file

# %%
# pdr.df = pd.read_excel(ufilepath, dtype=object, na_filter=False)

# %%
pdr.df.head(5)
# Out:
#       type                  alias  \
# 0  article   Hartung2022baltimore
# 1  Article  powell2022exploration
# 2  article         chung2022valid
# 3  ARTICLE              Li2022-gf
# 4  Article        Kudithipudi2022
#
#                                                title  \
# 0  The Baltimore Declaration toward the explorati...
# 1  Exploration of Residual Confounding in Analyse...
# 2  Valid two-sample graph testing via optimal tra...
# 3  Inpatient Administration of Alpha-1-Adrenergic...
# 4  Biological underpinnings for lifelong learning...
#
#                                               author  \
# 0  Thomas Hartung, Lena Smirnova, Itzy E Morales ...
# 1  Powell, Mike and Clark, Callahan and Alyakin, ...
# 2  Chung, Jaewon and Varjavand, Bijan and Arroyo-...
# 3  Li, Shilong and Jun, Tomi and Tyler, Jonathan ...
# 4  Kudithipudi, Dhireesha and Aguilar-Simon, Mari...
#
#                                            author+an  \
# 0                                       41=highlight
# 1                                                NaN
# 2  1=trainee,2=trainee,3=trainee,4=trainee,8=high...
# 3                                        9=highlight
# 4                                       38=highlight
#
#                        journal  year       keywords volume number  ... annote  \
# 0         Frontiers in Science  2022  peer-reviewed    NaN    NaN  ...    NaN
# 1            JAMA Network Open  2022  peer-reviewed      5     11  ...    NaN
# 2                         Stat  2022  peer-reviewed     11      1  ...    NaN
# 3                  Front. Med.  2022  peer-reviewed      9    NaN  ...    NaN
# 4  Nature Machine Intelligence  2022  peer-reviewed      4      3  ...    NaN
#
#   chapter editor  tag howpublished primaryclass urldate eprinttype copyright  \
# 0     NaN    NaN  NaN          NaN          NaN     NaN        NaN       NaN
# 1     NaN    NaN  NaN          NaN          NaN     NaN        NaN       NaN
# 2     NaN    NaN  NaN          NaN          NaN     NaN        NaN       NaN
# 3     NaN    NaN  NaN          NaN          NaN     NaN        NaN       NaN
# 4     NaN    NaN  NaN          NaN          NaN     NaN        NaN       NaN
#
#   annotation
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 51 columns]

# %%
# pdr.df.priority = pdr.df.priority.astype(float)
pdr.df.sort_values(['keywords'], ascending=True, inplace=True)

# %%
pdr.df.reset_index(drop=True)
# Out:
#               type                  alias  \
# 0    inproceedings                 j12019
# 1    inproceedings     hayden_naisys_2020
# 2    inproceedings            berlin_2017
# 3    inproceedings     falk_open_data2019
# 4    inproceedings       browneposter2019
# ..             ...                    ...
# 289        article  kiar2017comprehensive
# 290        article           graphyti2019
# 291        article               CloudReg
# 292        article     sinha2014automatic
# 293        article             Hayden2020
#
#                                                  title  \
# 0                   Clustering Multi-Modal Connectomes
# 1    A Biological Implementation of Lifelong Learni...
# 2    Processing and Analyzing Terascale Conjugate A...
# 3                NeuroData's Open Data Cloud Ecosystem
# 4       Forest Packing: Fast Parallel Decision Forests
# ..                                                 ...
# 289  A comprehensive cloud framework for accurate a...
# 290  Graphyti: A Semi-External Memory Graph Library...
# 291  CloudReg: automatic terabyte-scale cross-modal...
# 292  Automatic Annotation of Axoplasmic Reticula in...
# 293     Learning to rank via combining representations
#
#                                                 author  \
# 0    Chung, Jaewon and Pedigo, Benjamin D. and Prie...
# 1    Vogelstein, Joshua T. and Helm, Hayden and Ped...
# 2    Baden, Alex and Perlman, Eric and Collman, For...
# 3             Falk, Benjamin and Vogelstein, Joshua T.
# 4    Browne, James and Mhembere, Disa and Tomita, T...
# ..                                                 ...
# 289  Kiar, Gregory and Bridgeford, Eric and Chandra...
# 290  Mhembere, Disa and Zheng, Da and Vogelstein, J...
# 291  Chandrashekhar, Vikram and Tward, Daniel J and...
# 292            Sinha, A and Roncal, WG and Kasthuri, N
# 293  Helm, Hayden S. and Basu, Amitabh and Athreya,...
#
#                                              author+an         journal  year  \
# 0                      1=trainee;2=trainee;4=highlight             NaN  2019
# 1            2=trainee;3=trainee;4=trainee;1=highlight             NaN  2020
# 2                                1=trainee;5=highlight             NaN  2017
# 3                                          2=highlight             NaN  2019
# 4            1=trainee;2=trainee;3=trainee;4=highlight             NaN  2019
# ..                                                 ...             ...   ...
# 289  1=trainee;2=trainee;3=trainee;4=trainee;6=trai...         bioRxiv  2017
# 290                    1=trainee;2=trainee;3=highlight           arXiv  2019
# 291                             1=trainee,12=highlight  Nature Methods  2021
# 292                                                NaN           arXiv  2014
# 293                             1=trainee; 5=highlight           arXiv  2020
#
#     keywords volume number  ... annote chapter editor  tag howpublished  \
# 0     abspos    NaN    NaN  ...    NaN     NaN    NaN  NaN          NaN
# 1     abspos    NaN    NaN  ...    NaN     NaN    NaN  NaN          NaN
# 2     abspos    NaN    NaN  ...    NaN     NaN    NaN  NaN          NaN
# 3     abspos    NaN    NaN  ...    NaN     NaN    NaN  NaN          NaN
# 4     abspos    NaN    NaN  ...    NaN     NaN    NaN  NaN          NaN
# ..       ...    ...    ...  ...    ...     ...    ...  ...          ...
# 289     tech    NaN    NaN  ...    NaN     NaN    NaN  NaN          NaN
# 290     tech    NaN    NaN  ...    NaN     NaN    NaN  NaN          NaN
# 291     tech    NaN    NaN  ...    NaN     NaN    NaN  NaN          NaN
# 292     tech    NaN    NaN  ...    NaN     NaN    NaN  NaN          NaN
# 293     tech    NaN    NaN  ...    NaN     NaN    NaN  NaN          NaN
#
#     primaryclass urldate eprinttype copyright annotation
# 0            NaN     NaN        NaN       NaN        NaN
# 1            NaN     NaN        NaN       NaN        NaN
# 2            NaN     NaN        NaN       NaN        NaN
# 3            NaN     NaN        NaN       NaN        NaN
# 4            NaN     NaN        NaN       NaN        NaN
# ..           ...     ...        ...       ...        ...
# 289          NaN     NaN        NaN       NaN        NaN
# 290          NaN     NaN        NaN       NaN        NaN
# 291          NaN     NaN        NaN       NaN        NaN
# 292          NaN     NaN        NaN       NaN        NaN
# 293          NaN     NaN        NaN       NaN        NaN
#
# [294 rows x 51 columns]

# %%
pdr.transform(types='type',alias='alias',dirs='dev/')
