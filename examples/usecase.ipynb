# %%
# %cd ..
# Out:
# c:\Users\jongm\Desktop\temp_workspace\global\pandarize

# %%
import requests
import pandas as pd
from src.pandarize import Pandarize

# %%
url = 'https://raw.githubusercontent.com/neurodata/neurodata.io/deploy/content/bibs/people.bib'

# %%
pdr = Pandarize()
pdr.load(url)
pdr.fit()

# %%
pdr.df
# Out:
#             type             alias               author          usera  \
# 0   incollection              jovo    Joshua Vogelstein       Director
# 1   incollection               cep         Carey Priebe      Professor
# 2   incollection         alicewang  Alice Qingyang Wang  PhD candidate
# 3   incollection      rosslawrence        Ross Lawrence     MS advisee
# 4   incollection       sambitpanda         Sambit Panda    PhD Student
# ..           ...               ...                  ...            ...
# 74  incollection  sharmi_seshamani     Sharmi Seshamani
# 75  incollection         alexbaden           Alex Baden
# 76  incollection    florian_engert       Florian Engert
# 77  incollection     owen_randlett        Owen Randlett
# 78  incollection   onyeka_nnaemeka      Onyeka Nnaemeka
#
#                 userw month  year          number series  \
# 0   Chief Unity Ninja                          --
# 1                 NaN                          --
# 2         Peripatetic     2  2022      02/2022 --
# 3                 MIA     7  2019  07/19 -- 04/22   2022
# 4          Endangered     6  2019        06/19 --    NaN
# ..                ...   ...   ...             ...    ...
# 74                NaN
# 75                NaN
# 76                NaN
# 77                NaN
# 78                NaN
#
#                                              abstract userb  \
# 0
# 1
# 2                                                       Bsc
# 3   Lead m2g developer, maintainer of neuroparc, M...   BSE
# 4   A Ph.D. student who was also a Master's studen...   MSE
# ..                                                ...   ...
# 74
# 75
# 76
# 77
# 78
#
#                 userc     userd    keywords                doi  \
# 0            BME, JHU  director    director               jovo
# 1            AMS, JHU   faculty    director
# 2   Neuroscience, JHU   student  PhDstudent  AliceQingyangWang
# 3            BME, JHU   student   MSstudent           lawreros
# 4            BME, JHU   student  PhDstudent          sampan501
# ..                ...       ...         ...                ...
# 74                        other       other
# 75                        other       other
# 76                        other       other
# 77                        other       other
# 78                        other       other
#
#                                note  \
# 0                      jovo@jhu.edu
# 1                       cep@jhu.edu
# 2                   qwang88@jhu.edu
# 3                  rlawre18@jhu.edu
# 4                   spanda3@jhu.edu
# ..                              ...
# 74  sharmishtaas@alleninstitute.org
# 75                  abaden1@jhu.edu
# 76          florian@mcb.harvard.edu
# 77          owen.randlett@gmail.com
# 78             ognnaemeka@gmail.com
#
#                                               url      usere  \
# 0                         neurodata.io/about/jovo  safe-zone
# 1
# 2
# 3                                                  safe-zone
# 4                                       sampan.me  safe-zone
# ..                                            ...        ...
# 74
# 75                           github.com/alexbaden
# 76  www.mcb.harvard.edu/directory/florian-engert/
# 77
# 78
#
#                      file
# 0   vogelstein_joshua.jpg
# 1        priebe_carey.jpg
# 2          alice_wang.jpg
# 3       ross-lawrence.jpg
# 4        sambit-panda.jpg
# ..                    ...
# 74
# 75
# 76     florian-engert.jpg
# 77      owen-randlett.jpg
# 78    Onyeka-Nnaemeka.jpg
#
# [79 rows x 19 columns]
