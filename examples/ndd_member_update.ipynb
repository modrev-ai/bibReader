# %% [markdown]
# # NeuroData Member Update Protocol
# This notebook utilizes `pandarize` to parse people.bib file from neurodata.io and update the list

# %%
from pandarize.frame import Pandarizer
import pandas as pd

# %%
pdr = Pandarizer()
pdr.load('https://raw.githubusercontent.com/neurodata/neurodata.io/deploy/content/bibs/people.bib')
pdr.fit()

# %%
filepath = 'dev/intermediate.xlsx'
ufilepath = 'dev/intermediate-updated.xlsx'

# %%
pdr.df.head()
# Out:
#            type        alias             author                usera  \
# 0  incollection         jovo  Joshua Vogelstein             Director
# 1  incollection          cep       Carey Priebe            Professor
# 2  incollection     jongshin          Jong Shin    Software Engineer
# 3  incollection       adamli            Adam Li  Postdoctoral Fellow
# 4  incollection  tylertomita       Tyler Tomita  Postdoctoral Fellow
#
#                userw month  year     number series  \
# 0  Chief Unity Ninja                    --
# 1                                       --
# 2       Tech Support     9  2020  09/20 --
# 3                        9  2022   09/22 --
# 4                        8  2014  08/14 --
#
#                                             abstract  userb     userc  \
# 0                                                            BME, JHU
# 1                                                            AMS, JHU
# 2  Currently investigating the effect of inductiv...     MS  BME, JHU
# 3                                                     Ph.D.  BME, JHU
# 4  Developed Sparse Projection Oblique Randomer F...    MSE  BME, JHU
#
#       userd       keywords       doi                note  \
# 0  director       director      jovo        jovo@jhu.edu
# 1   faculty       director                   cep@jhu.edu
# 2     staff  staffresearch    jshinm     jshin69@jhu.edu
# 3   postdoc        postdoc  adam2392  Adam2392@gmail.com
# 4   postdoc        postdoc   ttomita   ttomita2@jhmi.edu
#
#                         url      usere                   file priority
# 0  neurodata.io/about/jovo/  safe-zone  vogelstein_joshua.jpg      0.0
# 1                                            priebe_carey.jpg      1.0
# 2                            safe-zone          jong_shin.png      2.0
# 3        adam2392.github.io                       adam_li.jpg      3.0
# 4                                            tomita_tyler.jpg      3.0

# %%
pdr.df.to_excel(filepath, index=False, engine='xlsxwriter')

# %% [markdown]
# Make changes to the downloaded and converted file

# %%
pdr.df = pd.read_excel(ufilepath, dtype=object, na_filter=False)

# %%
pdr.df.head(5)
# Out:
#            type        alias             author                usera  \
# 0  incollection         jovo  Joshua Vogelstein             Director
# 1  incollection          cep       Carey Priebe            Professor
# 2  incollection     jongshin          Jong Shin    Software Engineer
# 3  incollection       adamli            Adam Li  Postdoctoral Fellow
# 4  incollection  tylertomita       Tyler Tomita  Postdoctoral Fellow
#
#                    userw month  year     number series  \
# 0      Chief Unity Ninja                    --
# 1                                           --
# 2  Chief Digital Officer     9  2020  09/20 --
# 3                            9  2022   09/22 --   2022
# 4                            8  2014  08/14 --
#
#                                             abstract  userb     userc  \
# 0                                                            BME, JHU
# 1                                                            AMS, JHU
# 2  Currently investigating the effect of inductiv...     MS  BME, JHU
# 3                                                     Ph.D.  BME, JHU
# 4  Developed Sparse Projection Oblique Randomer F...    MSE  BME, JHU
#
#       userd       keywords       doi                note  \
# 0  director       director      jovo        jovo@jhu.edu
# 1   faculty       director                   cep@jhu.edu
# 2     staff  staffresearch    jshinm     jshin69@jhu.edu
# 3   postdoc        postdoc  adam2392  Adam2392@gmail.com
# 4   postdoc        postdoc   ttomita   ttomita2@jhmi.edu
#
#                         url      usere                   file priority
# 0  neurodata.io/about/jovo/  safe-zone  vogelstein_joshua.jpg      0.0
# 1                                            priebe_carey.jpg      1.0
# 2                            safe-zone          jong_shin.png      2.0
# 3        adam2392.github.io                       adam_li.jpg        9
# 4                                            tomita_tyler.jpg      3.0

# %%
pdr.df.priority = pdr.df.priority.astype(float)
pdr.df.sort_values(['priority'], ascending=True, inplace=True)#.reset_index(drop=True)

# %%
pdr.df.reset_index(drop=True)
# Out:
#             type            alias             author                 usera  \
# 0   incollection             jovo  Joshua Vogelstein              Director
# 1   incollection              cep       Carey Priebe             Professor
# 2   incollection         jongshin          Jong Shin     Software Engineer
# 3   incollection      tylertomita       Tyler Tomita   Postdoctoral Fellow
# 4   incollection             jhow   Javier Josue How   Postdoctoral Fellow
# ..           ...              ...                ...                   ...
# 82  incollection    ivankuznetsov     Ivan Kuznetsov
# 83  incollection         aligeisa          Ali Geisa    Research Assistant
# 84  incollection         gregkiar          Greg Kiar           MSE advisee
# 85  incollection  guilhermefranca   Guilherme Franca  Post-doctoral Fellow
# 86  incollection     rosslawrence      Ross Lawrence            MS advisee
#
#                     userw month  year          number series  \
# 0       Chief Unity Ninja                         --
# 1                                                 --
# 2   Chief Digital Officer     9  2020       09/20 --
# 3                             8  2014       08/14 --
# 4                            11  2020       11/20 --
# ..                    ...   ...   ...             ...    ...
# 82                            2  2015  02/15 -- 05/16   2016
# 83                            3  2020  03/20 -- 08/22   2022
# 84                            8  2014  08/14 -- 06/17   2017
# 85                            6  2016  06/16 -- 07/17   2017
# 86                    MIA     7  2019  07/19 -- 04/22   2022
#
#                                              abstract  userb  \
# 0
# 1
# 2   Currently investigating the effect of inductiv...     MS
# 3   Developed Sparse Projection Oblique Randomer F...    MSE
# 4   Javier studies how larval zebrafish learn how ...  Ph.D.
# ..                                                ...    ...
# 82  Currently an MD, PhD Candidate at the UPenn, w...    BSE
# 83  Researching progressive and lifelong learning ...     MS
# 84  Developer of m2g, the only existing "soup to n...    BSE
# 85  Worked on non-parametric clustering, with an a...  Ph.D.
# 86  Lead m2g developer, maintainer of neuroparc, M...    BSE
#
#                   userc               userd       keywords        doi  \
# 0              BME, JHU            director       director       jovo
# 1              AMS, JHU             faculty       director
# 2              BME, JHU               staff  staffresearch     jshinm
# 3              BME, JHU             postdoc        postdoc    ttomita
# 4   Neurosciences, UCSD             postdoc        postdoc  javierhow
# ..                  ...                 ...            ...        ...
# 82             BME, JHU           undergrad      undergrad
# 83             BME, JHU  faculty - research  staffresearch
# 84             BME, JHU             student      MSstudent      gkiar
# 85             CIS, JHU             postdoc        postdoc      guisf
# 86             BME, JHU             student      MSstudent   lawreros
#
#                       note                       url      usere  \
# 0             jovo@jhu.edu  neurodata.io/about/jovo/  safe-zone
# 1              cep@jhu.edu
# 2          jshin69@jhu.edu                            safe-zone
# 3        ttomita2@jhmi.edu
# 4             jhow@jhu.edu                            safe-zone
# ..                     ...                       ...        ...
# 82
# 83  realaligeisa@gmail.com
# 84                                  gkiar.github.com
# 85
# 86        rlawre18@jhu.edu                            safe-zone
#
#                      file  priority
# 0   vogelstein_joshua.jpg       0.0
# 1        priebe_carey.jpg       1.0
# 2           jong_shin.png       2.0
# 3        tomita_tyler.jpg       3.0
# 4          javier_how.jpg       3.0
# ..                    ...       ...
# 82                              9.0
# 83          ali_geisa.jpg       9.0
# 84          kiar_greg.jpg       9.0
# 85         franca-gui.jpg       9.0
# 86      ross-lawrence.jpg       9.0
#
# [87 rows x 20 columns]

# %%
pdr.transform(types='type',alias='alias',dirs='dev/')
